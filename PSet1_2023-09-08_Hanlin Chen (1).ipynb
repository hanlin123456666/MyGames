# %% [markdown]
# Problem set 1: Data importing and cleaning
#
# Due: 11:59pm on Friday, September 8 by uploading to github
#
# Your name:
#
# 1. Data importing: "data_finance.csv" contains a dataset with information about sales transactions. Write the appropriate code for each of the tasks below. This section should be completed without generative AI, but with open access to static online resources like course material, stackoverflow, blogs with sample code, etc.

# %%
# Load the pandas library
import pandas as pd
import os 

# Import the CSV file 'data_finance.csv' into a DataFrame
current_directory =os.getcwd()
print(f"current directory is {current_directory}")
data= pd.read_csv(f"{current_directory}/raw/data_finance.csv")
#data= pd.read_csv("/Users/chenhanlin/Documents/vandy 23 fall/DS 5610 EDA/Assignment/data/raw/data_finance.csv")

# Display the column names
print(data.head)

# Identify the data types of each column
print(data.dtypes)

# Display the first 5 rows of the DataFrame
print(data.loc[:4,:])

# Display the last 5 rows of the DataFrame
print(data.tail(5))

# Display a random sample of 5 rows
print(data.sample(n=5))

# Calculate the total number of rows and columns in the DataFrame
print(data.shape)

# Display summary statistics for the quantity and price columns
print(data[['quantity','price']].describe())
# Out:
# current directory is /Users/chenhanlin/Documents/vandy 23 fall/DS 5610 EDA/Assignment/data
# <bound method NDFrame.head of     transaction_id          product_name  quantity  price
# 0                1                 Apple         7  12.34
# 1                2                Banana         2  19.05
# 2                3                Cherry         9   5.81
# 3                4                  Date         4   1.76
# 4                5            Elderberry         8  10.45
# 5                6                   Fig         3  18.22
# 6                7                 Grape         1   7.09
# 7                8              Honeydew         5  23.48
# 8                9             Jackfruit        10   2.56
# 9               10                  Kiwi         6   9.71
# 10              11                 Lemon         7   4.23
# 11              12                 Mango         3  14.12
# 12              13             Nectarine         2   6.87
# ...

# %% [markdown]
# 2. Generative AI comparison. Use a reliable generative AI like ChatGPT, Claude, Bing, Jupyter AI, etc. to answer the same questions as Section 1. You should alter the prompt given to the AI to maximize the accuracy and efficiency of its output. Paste both your prompt and the generative AI's output below.

# %%
# Prompt: You are a pandas expert. Help me write these codes: Import the CSV file 'data_finance.csv' into a DataFrame; Display the column names;Identify the data types of each column; Display the first 5 rows of the DataFrame; Display the last 5 rows of the DataFrame; Display a random sample of 5 rows; Calculate the total number of rows and columns in the DataFrame; Display summary statistics for the quantity and price columns;

# AI generated code
# Load Pandas and import the CSV file 'data_finance.csv' into a DataFrame
import pandas as pd
data = pd.read_csv('/mnt/data/data_finance.csv')

# Display the column names
print(data.columns)

# Identify the data types of each column
print(data.dtypes)

# Display the first 5 rows of the DataFrame
print(data.head())

#Display the last 5 rows of the DataFrame:
print(data.tail())

#Display a random sample of 5 rows:
print(data.sample(5))

#Calculate the total number of rows and columns in the DataFrame:
num_rows, num_columns = data.shape
print(f'Total Rows: {num_rows}')
print(f'Total Columns: {num_columns}')

#Display summary statistics for the quantity and price columns:
print(data[['quantity', 'price']].describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[67], line 6
#       1 # Prompt: You are a pandas expert. Help me write these codes: Import the CSV file 'data_finance.csv' into a DataFrame; Display the column names;Identify the data types of each column; Display the first 5 rows of the DataFrame; Display the last 5 rows of the DataFrame; Display a random sample of 5 rows; Calculate the total number of rows and columns in the DataFrame; Display summary statistics for the quantity and price columns;
#       2
#       3 # AI generated code
#       4 # Load Pandas and import the CSV file 'data_finance.csv' into a DataFrame
#       5 import pandas as pd
# ----> 6 data = pd.read_csv('/mnt/data/data_finance.csv')
#       8 # Display the column names
#       9 print(data.columns)
#
# ...

# %% [markdown]
# 3. Data cleaning: "data_students.tsv" contains a dataset with information about students. Write the appropriate code for each of the tasks below. This section should be completed without generative AI, but with open access to static online resources like course material, stackoverflow, blogs with sample code, etc.

# %%
# Import "data_students.tsv" into a dataframe
import pandas as pd
current_directory =os.getcwd()
print(f"current directory is {current_directory}")
df = pd.read_csv(f"{current_directory}/raw/data_students.tsv",sep='\t')
print(df)

#Rename the columns to improve machine and human-readability
df = df.rename ({'name':'student_name',"student's age":'student_age','sex of student':'student_sex','location':'student_location','math grade':'grade_math','science':'grade_science','history':'grade_history', 'grade in english':'grade_english'}, axis=1)
print(df)

# Display the number of missing values in each column
print(df.isnull().count())

# Create a new column identifying whether the age column is missing
df['check_age_missing'] = df['student_age'].isnull()

# Replace missing values in the 'age' column with the mean age
df['student_age'] = df['student_age'].fillna(df['student_age'].mean()).round().astype(int)
print(df)

# Convert the 'gender' column to lowercase
df['student_sex']=df['student_sex'].str.lower()
print(df['student_sex'])

# Split the location column into separate columns for city and state
df[['student_location_city','student_location_state']] = df['student_location'].str.split(", ",expand= True)
print(df)

# Save the cleaned data to a new CSV file with an appropriate name
df.to_csv('data_students_cleaned.csv')
# Out:
# current directory is /Users/chenhanlin/Documents/vandy 23 fall/DS 5610 EDA/Assignment/data
#     student_id       name  student's age sex of student            location  \
# 0            1      Alice           23.0         Female         Houston, TX
# 1            2   Benjamin           31.0           Male         Phoenix, AZ
# 2            3  Charlotte           30.0        Neither         Chicago, IL
# 3            4     Daniel           24.0        Unknown          Denver, CO
# 4            5    Eleanor            NaN           male         Atlanta, GA
# 5            6      Fiona           27.0         Female           Miami, FL
# 6            7      Grace           28.0        neither         Seattle, WA
# 7            8      Henry           21.0        Unknown          Boston, MA
# 8            9   Isabella           28.0           Male          Austin, TX
# 9           10       Jack           19.0         female        Portland, OR
# ...

# %% [markdown]
# 4. Generative AI comparison. Use a reliable generative AI like ChatGPT, Claude, Bing, Jupyter AI, etc. to answer the same questions as Section 3. You should alter the prompt given to the AI to maximize the accuracy and efficiency of its output. Paste both your prompt and the generative AI's output below.

# %%
# 1 st prompt: You are a great expert in pandas to clean the data. Here is the data. Can you help do the following things? 

# Import "data_students.tsv" into a dataframe

# Rename the columns to improve machine and human-readability

# Display the number of missing values in each column

# Create a new column identifying whether the age column is missing

# Replace missing values in the 'age' column with the mean age

# Convert the 'gender' column to lowercase

# Split the location column into separate columns for city and state

# Save the cleaned data to a new CSV file with an appropriate name

# 2nd prompt: can you show all the codes in one time? 

# output

import pandas as pd

# 1. Import the "data_students.tsv" into a dataframe
df = pd.read_csv("/mnt/data/data_students.tsv", sep="\t")

# 2. Rename the columns to improve machine and human-readability
column_names = {
    "student's age": "age",
    "sex of student": "gender",
    "math grade": "math_grade",
    "science": "science_grade",
    "history": "history_grade",
    "grade in english": "english_grade"
}
df.rename(columns=column_names, inplace=True)

# 3. Display the number of missing values in each column (We displayed this in the output above)
missing_values = df.isnull().sum()

# 4. Create a new column identifying whether the 'age' column is missing
df['age_missing'] = df['age'].isnull()

# 5. Replace missing values in the 'age' column with the mean age
mean_age = df['age'].mean()
df['age'].fillna(mean_age, inplace=True)

# 6. Convert the 'gender' column to lowercase
df['gender'] = df['gender'].str.lower()

# 7. Split the 'location' column into separate columns for city and state
df[['city', 'state']] = df['location'].str.split(',', expand=True)
df.drop(columns='location', inplace=True)

# 8. Save the cleaned data to a new CSV file
output_file_path = "/mnt/data/cleaned_students_data.csv"
df.to_csv(output_file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 26
#      23 import pandas as pd
#      25 # 1. Import the "data_students.tsv" into a dataframe
# ---> 26 df = pd.read_csv("/mnt/data/data_students.tsv", sep="\t")
#      28 # 2. Rename the columns to improve machine and human-readability
#      29 column_names = {
#      30     "student's age": "age",
#      31     "sex of student": "gender",
#    (...)
#      35     "grade in english": "english_grade"
#      36 }
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# 5. Generative AI evaluation. Compare the code you produced using static sources to that produced by the generative AI. Write 2-3 paragraphs evaluating the strengths and weaknesses of both approaches. In doing so, you should answer the following questions:
# * Having now seen the code produced by Generative AI, how would you have written your code differently?
# * Where does Generative AI excel, and where did it fall short?
# * What was important in writing your prompt?

# %% [markdown]
# Before the advent of Generative AI, I primarily wrote codes on my own and turned to StackOverflow when faced with challenges. Now, if the time is limited, I will ask Generative AI for help; however I will critically evaluate the codes produced by it before using the codes.
#
# Generative AI has expedited my problem-solving process, offering real-time responses tailored to my queries. However, I still find myself sifting through static resources to validate that the answers correspond accurately to my questions. It's noteworthy that Generative AI tools, like ChatGPT, lack access to the most recent information unless augmented with plugins. Conversely, static online resources benefit from the collective expertise of numerous contributors, ensuring the content remains current. Furthermore, ChatGPT's knowledge is based on data up to 2021. As such, the quality of its responses hinges on this training data, which carries the risk of producing incorrect or less-than-optimal answers. However, answers on static online resources undergo rigorous scrutiny by a variety of users. High acceptance rates signal the credibility of these answers, and the diverse perspectives offered can enhance one's ability to adapt solutions to various scenarios.
#
# When crafting a prompt for ChatGPT, both clarity and context are paramount. ChatGPT struggles with retaining information and managing extended prompts. Hence, it's crucial to pose questions that are concise, explicit, and clear. It's advisable to ask all related questions in one time since the model lacks the capability to remember past interactions over extended periods. Additionally, providing context, such as setting a specific persona for ChatGPT, can significantly improve its comprehension of the query, leading to more efficient and relevant responses.
